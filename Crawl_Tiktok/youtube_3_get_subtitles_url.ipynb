# %%
import requests
import json
from datetime import datetime

# Airtable configuration
AIRTABLE_BASE_ID = 'app7mcJMf9O8GQRal'
AIRTABLE_API_KEY = ''
TABLE_NAME = 'youtube_post'
AIRTABLE_URL = f"https://api.airtable.com/v0/{AIRTABLE_BASE_ID}/{TABLE_NAME}"

# YouTube API configuration
YOUTUBE_API_HOST = "youtube-media-downloader.p.rapidapi.com"
YOUTUBE_API_KEY = ""

def get_youtube_video_details(video_id):
    url = f"https://{YOUTUBE_API_HOST}/v2/video/details"
    
    headers = {
        "X-RapidAPI-Key": YOUTUBE_API_KEY,
        "X-RapidAPI-Host": YOUTUBE_API_HOST
    }
    
    params = {"videoId": video_id}
    
    response = requests.get(url, headers=headers, params=params)
    return response.json()

def update_airtable(record_id, video_data):
    headers = {
        "Authorization": f"Bearer {AIRTABLE_API_KEY}",
        "Content-Type": "application/json"
    }
    
    # Xử lý subtitles một cách an toàn hơn
    subtitles_items = video_data.get("subtitles", {}).get("items", [])
    subtitles_url = subtitles_items[0].get("url", "") if subtitles_items else ""
    
    fields = {
        "description": video_data.get("description", ""),
        "username": video_data.get("channel", {}).get("handle", ""),
        "published_time": video_data.get("publishedTime", ""),
        "viewCount": video_data.get("viewCount", 0),
        "likeCount": video_data.get("likeCount", 0),
        "subtitles_url": subtitles_url
    }
    
    data = {
        "records": [{
            "id": record_id,
            "fields": fields
        }]
    }
    
    print("Data gửi đi:", json.dumps(data, indent=2))
    
    response = requests.patch(AIRTABLE_URL, headers=headers, json=data)
    
    print("Response status code:", response.status_code)
    print("Response body:", response.text)
    
    return response.json()

def get_airtable_records():
    headers = {
        "Authorization": f"Bearer {AIRTABLE_API_KEY}"
    }
    
    params = {
        "view": "0_no_sub"
    }
    
    response = requests.get(AIRTABLE_URL, headers=headers, params=params)
    if response.status_code != 200:
        print("Lỗi xác thực Airtable:", response.status_code)
        print("Response:", response.text)
        return None
        
    return response.json()

def main():
    # Lấy danh sách records từ Airtable
    airtable_records = get_airtable_records()
    
    for record in airtable_records.get("records", []):
        record_id = record["id"]
        # Giả sử bạn có trường video_id trong Airtable
        video_id = record["fields"].get("video_id")
        
        if video_id:
            # Lấy thông tin video từ YouTube API
            video_data = get_youtube_video_details(video_id)
            
            if video_data.get("status"):
                # Cập nhật thông tin vào Airtable
                update_result = update_airtable(record_id, video_data)
                print(f"Đã cập nhật record {record_id}")
            else:
                print(f"Không thể lấy thông tin video {video_id}")

if __name__ == "__main__":
    main()
# Out:
# Data gửi đi: {
#   "records": [
#     {
#       "id": "recCcpsfzxiMtJaZ9",
#       "fields": {
#         "description": "\"I know many English words, but when I speak English, I forget all of them\". \nIf this is your problem too, this video is for you! In this video you will learn a 100% proven method to use when learning new English vocabulary as well as improving your speaking and fluency. \n\nEnglish language is full of words. But do we need to know all of them to speak English? of course not! In fact, you can speak English by knowing 1000 words only (although an advanced level requires at least 10-15k words). However, the problem is sometimes you know these English words, but when you want to speak English, you are lost for words. Why is that?\n\nThis video will reveal the secret for you. It is not about the quantity of English vocabulary you learn, but quality of the English words and method of learning new English vocabulary. I have explained a method that has worked for all my student's who had the same problem. Don't miss it!\n\nAs always, don't forget to let me know what you think about this method!",
#         "username": "@POCEnglish",
#         "published_time": "2021-11-24T03:00:19-08:00",
#         "viewCount": 8095256,
#         "likeCount": 200267,
#         "subtitles_url": ""
#       }
#     }
#   ]
# }
# Response status code: 200
# Response body: {"records":[{"id":"recCcpsfzxiMtJaZ9","createdTime":"2024-10-29T09:29:30.000Z","fields":{"published_time":"2021-11-24T11:00:19.000Z","viewCount":8095256,"title":"Forget Words When Speaking English? Here Is Why!","length":849,"video_id":"iNhZnH9bQLc","description":"\"I know many English words, but when I speak English, I forget all of them\". \nIf this is your problem too, this video is for you! In this video you will learn a 100% proven method to use when learning new English vocabulary as well as improving your speaking and fluency. \n\nEnglish language is full of words. But do we need to know all of them to speak English? of course not! In fact, you can speak English by knowing 1000 words only (although an advanced level requires at least 10-15k words). However, the problem is sometimes you know these English words, but when you want to speak English, you are lost for words. Why is that?\n\nThis video will reveal the secret for you. It is not about the quantity of English vocabulary you learn, but quality of the English words and method of learning new English vocabulary. I have explained a method that has worked for all my student's who had the same problem. Don't miss it!\n\nAs always, don't forget to let me know what you think about this method!","username":"@POCEnglish","likeCount":200267}}]}
# Đã cập nhật record recCcpsfzxiMtJaZ9
# Data gửi đi: {
#   "records": [
#     {
#       "id": "recYTK3V5l3pnFBS8",
#       "fields": {
#         "description": "\"I know many English words, but when I speak English, I forget all of them\". \nIf this is your problem too, this video is for you! In this video you will learn a 100% proven method to use when learning new English vocabulary as well as improving your speaking and fluency. \n\nEnglish language is full of words. But do we need to know all of them to speak English? of course not! In fact, you can speak English by knowing 1000 words only (although an advanced level requires at least 10-15k words). However, the problem is sometimes you know these English words, but when you want to speak English, you are lost for words. Why is that?\n\nThis video will reveal the secret for you. It is not about the quantity of English vocabulary you learn, but quality of the English words and method of learning new English vocabulary. I have explained a method that has worked for all my student's who had the same problem. Don't miss it!\n\nAs always, don't forget to let me know what you think about this method!",
#         "username": "@POCEnglish",
#         "published_time": "2021-11-24T03:00:19-08:00",
#         "viewCount": 8095256,
#         "likeCount": 200267,
#         "subtitles_url": ""
#       }
#     }
#   ]
# }
# Response status code: 200
# Response body: {"records":[{"id":"recYTK3V5l3pnFBS8","createdTime":"2024-10-29T19:49:49.000Z","fields":{"video_id":"iNhZnH9bQLc","title":"Forget Words When Speaking English? Here Is Why!","length":849,"published_time":"2021-11-24T11:00:19.000Z","viewCount":8095256,"username":"@POCEnglish","description":"\"I know many English words, but when I speak English, I forget all of them\". \nIf this is your problem too, this video is for you! In this video you will learn a 100% proven method to use when learning new English vocabulary as well as improving your speaking and fluency. \n\nEnglish language is full of words. But do we need to know all of them to speak English? of course not! In fact, you can speak English by knowing 1000 words only (although an advanced level requires at least 10-15k words). However, the problem is sometimes you know these English words, but when you want to speak English, you are lost for words. Why is that?\n\nThis video will reveal the secret for you. It is not about the quantity of English vocabulary you learn, but quality of the English words and method of learning new English vocabulary. I have explained a method that has worked for all my student's who had the same problem. Don't miss it!\n\nAs always, don't forget to let me know what you think about this method!","likeCount":200267}}]}
# Đã cập nhật record recYTK3V5l3pnFBS8
# Data gửi đi: {
#   "records": [
#     {
#       "id": "reczSbSh8tDztYJeu",
#       "fields": {
#         "description": "1-Page PDF Summary: https://bit.ly/3ty2pGO\nBook Link: https://amzn.to/2IJ4SrJ\nFREE Audiobook Trial: http://amzn.to/2ypaVsP\n\nAnimated core message from Dale Carnegie's book 'How to Win Friends and Influence People.'\n\nTo get every 1-Page PDF Book Summary for this channel: https://gum.co/cmOOM\n\nThis video is a Lozeron Academy LLC production - www.ProductivityGame.com",
#         "username": "@ProductivityGame",
#         "published_time": "2018-05-14T21:08:35-07:00",
#         "viewCount": 1028006,
#         "likeCount": 25188,
#         "subtitles_url": "https://www.youtube.com/api/timedtext?v=_uA_HkOJGjY&ei=0T4hZ5jcKfK9kucP7rynuQU&caps=asr&opi=112496729&exp=xpo,xbt&xoaf=7&hl=en&ip=0.0.0.0&ipbits=0&expire=1730257217&sparams=ip,ipbits,expire,v,ei,caps,opi,exp,xoaf&signature=DE0E732ECB16974D786D0C504F522D9D84C2539E.53AA489192EAC97720EEAC3B93CBC768F0F4D891&key=yt8&kind=asr&lang=en"
#       }
#     }
#   ]
# }
# Response status code: 200
# Response body: {"records":[{"id":"reczSbSh8tDztYJeu","createdTime":"2024-10-29T09:34:11.000Z","fields":{"published_time":"2018-05-15T04:08:35.000Z","viewCount":1028006,"title":"HOW TO WIN FRIENDS AND INFLUENCE PEOPLE by Dale Carnegie | Animated Core Message","length":579,"video_id":"_uA_HkOJGjY","description":"1-Page PDF Summary: https://bit.ly/3ty2pGO\nBook Link: https://amzn.to/2IJ4SrJ\nFREE Audiobook Trial: http://amzn.to/2ypaVsP\n\nAnimated core message from Dale Carnegie's book 'How to Win Friends and Influence People.'\n\nTo get every 1-Page PDF Book Summary for this channel: https://gum.co/cmOOM\n\nThis video is a Lozeron Academy LLC production - www.ProductivityGame.com","username":"@ProductivityGame","likeCount":25188,"subtitles_url":"https://www.youtube.com/api/timedtext?v=_uA_HkOJGjY&ei=0T4hZ5jcKfK9kucP7rynuQU&caps=asr&opi=112496729&exp=xpo,xbt&xoaf=7&hl=en&ip=0.0.0.0&ipbits=0&expire=1730257217&sparams=ip,ipbits,expire,v,ei,caps,opi,exp,xoaf&signature=DE0E732ECB16974D786D0C504F522D9D84C2539E.53AA489192EAC97720EEAC3B93CBC768F0F4D891&key=yt8&kind=asr&lang=en"}}]}
# Đã cập nhật record reczSbSh8tDztYJeu
# Data gửi đi: {
#   "records": [
#     {
#       "id": "recLJdpHhybJuUC1D",
#       "fields": {
#         "description": "\u2705Download my English book (for FREE!): \nhttps://pocenglish.com/book/\n\n\u2705Become a channel member:\nhttps://www.youtube.com/channel/UC9CohF5QlJr3md4h9iTLzOg/join\n--------------------------------\nIn this video, you'll learn 30 common English idioms that native speakers use all the time. Idioms are phrases that don't mean what they seem to on the surface, but once you understand them, they can really help you communicate more fluently and naturally. \n\nYou'll learn the meanings and usage of these 30 essential idioms, along with example sentences and tips for using them in conversation. By the end of the video, you'll be equipped with a powerful tool for sounding more like a native English speaker and communicating with greater confidence and ease.\n\nTo navigate easily, here are the timestamps:\n\u27a1\ufe0f Part 1\n00:00 Intro\n01:01 Beat around the bush\n01:37 Bite off more than you can chew\n02:28 A blessing in disguise\n03:50 Give somebody the benefit of the doubt\n04:37 Kill two birds with one stone\n05:22 Let the cat out of the bag\n05:57 Miss the boat\n06:37 Take something with a grain of salt\n07:50 Be up in the air\n08:14 Stab somebody in the back\n08:51 DIALOGUE 1\n\n\u27a1\ufe0fPart 2\n09:52 Lose your touch\n10:38 Sit tight\n11:08 Face the music\n11:37 Get over somebody/ something\n12:22 Crunch time \n13:03 Get out of hand\n13:29 Get something out of your system\n13:55 Hang in there\n14:21 Throw caution to the wind\n15:03 Call it a day\n15:23 QUIZ TIME!\n\n\u27a1\ufe0fPart 3\n17:58 Be on cloud nine\n18:23 Be under the weather\n18:47 Speak of the devil\n19:15 Ignorance is bliss\n19:57 That ship has sailed\n20:30 Bark up the wrong tree\n21:12 On top of the world\n21:35 Full of the joys of spring\n22:06 Kick the bucket\n22:37 Like death warmed up\n22:55 DIALOGUE 2\n\nI hope you enjoy this lesson!\nCheers\nMaddy!",
#         "username": "@POCEnglish",
#         "published_time": "2023-10-18T06:00:17-07:00",
#         "viewCount": 1016061,
#         "likeCount": 25195,
#         "subtitles_url": "https://www.youtube.com/api/timedtext?v=QVAFrOl0VLs&ei=1D4hZ9jdK8SZsfIPq66O6As&caps=asr&opi=112496729&exp=xpo,xbt&xoaf=7&hl=en&ip=0.0.0.0&ipbits=0&expire=1730257220&sparams=ip,ipbits,expire,v,ei,caps,opi,exp,xoaf&signature=E44D568F6EA1C79FAFD98CE8E67829D5220F654B.41719DE000E22A6B0781CDEE02B4C5D87CB8B7E1&key=yt8&kind=asr&lang=en"
#       }
#     }
#   ]
# }
# Response status code: 200
# Response body: {"records":[{"id":"
key=yt8&kind=asr&lang=en"
#       }
#     }
#   ]
# }
# Response status code: 200
# Response body: {"records":[{"id":"recoI3LPKH6lvRCPo","createdTime":"2024-10-29T19:49:41.000Z","fields":{"video_id":"Svi8vexUAX4","title":"Stop Saying \"I THINK\"! In English Language!","length":422,"published_time":"2021-12-19T09:30:08.000Z","viewCount":925329,"username":"@POCEnglish","description":"In this English vocabulary lesson, you will learn some alternatives to say instead of I Think! Is it wrong to say \"I think\" all the time? No. Does it show you have limited vocabulary? Yes! Therefore, learning different ways to say I Think will increase your vocabulary and help you sound more confident in English language.\n\n0:00 Introduction\n0:49 from my point of view\n2:23 If you ask me\n3:44 3. as far as I'm concerned\n4:34 as far as I can\n5:56 I would say","likeCount":51028,"subtitles_url":"https://www.youtube.com/api/timedtext?v=Svi8vexUAX4&ei=5j4hZ4Y96sGx8g-R1beZDQ&caps=asr&opi=112496729&exp=xpo,xbt&xoaf=7&hl=en&ip=0.0.0.0&ipbits=0&expire=1730257238&sparams=ip,ipbits,expire,v,ei,caps,opi,exp,xoaf&signature=7B4235E5E570855A56B2F8BB78B3314246922E52.1049274AB27F55516F0779E8D0BAD08BCC824839&key=yt8&kind=asr&lang=en"}}]}
# Đã cập nhật record recoI3LPKH6lvRCPo
# Data gửi đi: {
#   "records": [
#     {
#       "id": "recLNwSxTstDhYvYr",
#       "fields": {
#         "description": "In this English vocabulary lesson, you will learn some alternatives to say instead of I Think! Is it wrong to say \"I think\" all the time? No. Does it show you have limited vocabulary? Yes! Therefore, learning different ways to say I Think will increase your vocabulary and help you sound more confident in English language.\n\n0:00 Introduction\n0:49 from my point of view\n2:23 If you ask me\n3:44 3. as far as I'm concerned\n4:34 as far as I can\n5:56 I would say",
#         "username": "@POCEnglish",
#         "published_time": "2021-12-19T01:30:08-08:00",
#         "viewCount": 925329,
#         "likeCount": 51028,
#         "subtitles_url": "https://www.youtube.com/api/timedtext?v=Svi8vexUAX4&ei=6T4hZ4m1BJ6AsfIPvNzfyAs&caps=asr&opi=112496729&exp=xpo,xbt&xoaf=7&hl=en&ip=0.0.0.0&ipbits=0&expire=1730257241&sparams=ip,ipbits,expire,v,ei,caps,opi,exp,xoaf&signature=80B2E4A66BBD14850FF0E763B0E58DF34CDD1FDD.D17114376989053180062401643B755AE2B0F4F9&key=yt8&kind=asr&lang=en"
#       }
#     }
#   ]
# }
# Response status code: 200
# Response body: {"records":[{"id":"recLNwSxTstDhYvYr","createdTime":"2024-10-29T09:29:22.000Z","fields":{"published_time":"2021-12-19T09:30:08.000Z","viewCount":925329,"title":"Stop Saying \"I THINK\"! In English Language!","length":422,"video_id":"Svi8vexUAX4","description":"In this English vocabulary lesson, you will learn some alternatives to say instead of I Think! Is it wrong to say \"I think\" all the time? No. Does it show you have limited vocabulary? Yes! Therefore, learning different ways to say I Think will increase your vocabulary and help you sound more confident in English language.\n\n0:00 Introduction\n0:49 from my point of view\n2:23 If you ask me\n3:44 3. as far as I'm concerned\n4:34 as far as I can\n5:56 I would say","username":"@POCEnglish","likeCount":51028,"subtitles_url":"https://www.youtube.com/api/timedtext?v=Svi8vexUAX4&ei=6T4hZ4m1BJ6AsfIPvNzfyAs&caps=asr&opi=112496729&exp=xpo,xbt&xoaf=7&hl=en&ip=0.0.0.0&ipbits=0&expire=1730257241&sparams=ip,ipbits,expire,v,ei,caps,opi,exp,xoaf&signature=80B2E4A66BBD14850FF0E763B0E58DF34CDD1FDD.D17114376989053180062401643B755AE2B0F4F9&key=yt8&kind=asr&lang=en"}}]}
# Đã cập nhật record recLNwSxTstDhYvYr
# Data gửi đi: {
#   "records": [
#     {
#       "id": "recKDT4jked4OKXkr",
#       "fields": {
#         "description": "1-Page PDF Summary: https://bit.ly/3Hh1dNy\nBook Link: http://amzn.to/1UF7Xn8\nFREE Audiobook Trial: http://amzn.to/2ypaVsP\n\nAnimated core message of Angela Duckworth's book 'Grit'.\n\nTo get every 1-Page PDF Book Summary for this channel: https://gum.co/cmOOM\n\nThis video is a Lozeron Academy LLC production - www.ProductivityGame.com",
#         "username": "@ProductivityGame",
#         "published_time": "2016-06-09T20:00:01-07:00",
#         "viewCount": 894482,
#         "likeCount": 12957,
#         "subtitles_url": "https://www.youtube.com/api/timedtext?v=sWctLEdIgi4&ei=7D4hZ5fhEYSKsfIP7PvtmA0&caps=asr&opi=112496729&exp=xpo,xbt&xoaf=7&hl=en&ip=0.0.0.0&ipbits=0&expire=1730257244&sparams=ip,ipbits,expire,v,ei,caps,opi,exp,xoaf&signature=445CC995E73FFFC98B6CDEE3F20B493FE186D813.B63BE5EBC7FBDD4D745B18BE5D3BEDCD986E7639&key=yt8&kind=asr&lang=en"
#       }
#     }
#   ]
# }
# Response status code: 200
# Response body: {"records":[{"id":"
key=yt8&kind=asr&lang=en"
#       }
#     }
#   ]
# }
# Response status code: 200
# Response body: {"records":[{"id":"recR67XocEcKQOJ34","createdTime":"2024-10-29T19:52:45.000Z","fields":{"video_id":"_SzvtJMrXx0","title":"13 THINGS MENTALLY STRONG PEOPLE DON'T DO by Amy Morin | Core Message","length":565,"published_time":"2020-04-06T04:06:28.000Z","viewCount":823958,"username":"@ProductivityGame","description":"1-Page PDF Summary: https://bit.ly/3Hjk3Uq\nBook Link: https://amzn.to/34hONBQ\nFREE Audiobook Trial: http://amzn.to/2ypaVsP\n\nAnimated core message from Amy Morin's book '13 Things Mentally Strong People Don't Do.'\n\nTo get every 1-Page PDF Book Summary for this channel go here: https://gum.co/cmOOM\n\nThis video is a Lozeron Academy LLC production - www.ProductivityGame.com","likeCount":24184,"subtitles_url":"https://www.youtube.com/api/timedtext?v=_SzvtJMrXx0&ei=8j4hZ5PONuqYsfIPhYf38AE&caps=asr&opi=112496729&exp=xpo,xbt&xoaf=7&hl=en&ip=0.0.0.0&ipbits=0&expire=1730257250&sparams=ip,ipbits,expire,v,ei,caps,opi,exp,xoaf&signature=0B1EF50B55797D70075B459691F3D8870FA35D9A.7B81D563CA63EFE71B9B4589DD6D0161C072D640&key=yt8&kind=asr&lang=en"}}]}
# Đã cập nhật record recR67XocEcKQOJ34
# Data gửi đi: {
#   "records": [
#     {
# ...
#         "username": "@JustinSung",
#         "published_time": "2024-02-29T04:10:27-08:00",
#         "viewCount": 335614,
#         "likeCount": 15101,
#         "subtitles_url": "https://www.youtube.com/api/timedtext?v=NqxUExCZJ5Y&ei=Nj8hZ763Md2XsfIP0p6toQU&caps=asr&opi=112496729&exp=xpo,xbt&xoaf=7&hl=en&ip=0.0.0.0&ipbits=0&expire=1730257318&sparams=ip,ipbits,expire,v,ei,caps,opi,exp,xoaf&signature=6BA6C7A4471865833463163D7CF4D065A54CD9CB.D65AE35A552A6823B1D4E008B6E5E28BFF61E7AF&key=yt8&kind=asr&lang=en"
#       }
#     }
#   ]
# }
# Response status code: 200
# Response body: {"records":[{"id":"recDF6ApQogCQ3mRB","createdTime":"2024-10-29T09:38:49.000Z","fields":{"published_time":"2024-02-29T12:10:27.000Z","viewCount":335614,"title":"What I Learned after 5000 Hours of Mind Mapping","length":1390,"video_id":"NqxUExCZJ5Y","description":"Learn key mind-mapping principles from a decade of practice.\n\nJoin my Learning Drops newsletter (free): https://bit.ly/3VmJQDM\nEvery week, I distil what really works for improving results, memory, depth of understanding, and knowledge application from over a decade of coaching into bite-sized emails.\n\nLearner Type Quiz (free) - Figure out your learning strengths and weaknesses: https://bit.ly/454YJht\n\nLearning System Diagnostic Quiz (free) - See how the way you learn compares to top learners: https://bit.ly/4aGlCsI\n\nResearch summary on learning (free): https://icanstudy.com/report-on-learning\n\nWatch my TEDx talk on learning to learn (top 1% viewed in 2022): https://www.youtube.com/watch?v=TQXMl4GycD0\n\n\n=== Paid Training Program ===\n\nJoin my step-by-step learning skills program to improve your results: https://bit.ly/3ww88kN\n\n(Designed for busy students and professionals aiming to achieve top results without endless studying. 77% of our students cover the same amount of study material in 30% less time within 1 month.)\n\n\n=== Timestamps ===\n\n00:00 Intro\n00:30 Secret 1\n07:37 Secret 2\n11:06 Secret 3\n20:26 Secret 4\n\n\n=== About Dr Justin Sung ===\n\nDr. Justin Sung is a world-renowned expert in self-regulated learning, certified teacher, research author, and former medical doctor. He has guest lectured on learning skills at Monash University for Master’s and PhD students in Education and Medicine. Over the past decade, he has empowered tens of thousands of learners worldwide to dramatically improve their academic performance, learning efficiency, and motivation.\n\nInstagram: https://instagram.com/drjustinsung\nTikTok: https://tiktok.com/@drjustinsung\nFacebook: https://www.facebook.com/drjustinsung\nLinkedIn: https://www.linkedin.com/in/justin-sung/\nX: https://x.com/drjustinsung","username":"@JustinSung","likeCount":15101,"subtitles_url":"https://www.youtube.com/api/timedtext?v=NqxUExCZJ5Y&ei=Nj8hZ763Md2XsfIP0p6toQU&caps=asr&opi=112496729&exp=xpo,xbt&xoaf=7&hl=en&ip=0.0.0.0&ipbits=0&expire=1730257318&sparams=ip,ipbits,expire,v,ei,caps,opi,exp,xoaf&signature=6BA6C7A4471865833463163D7CF4D065A54CD9CB.D65AE35A552A6823B1D4E008B6E5E28BFF61E7AF&key=yt8&kind=asr&lang=en"}}]}
# Đã cập nhật record recDF6ApQogCQ3mRB
# Không thể lấy thông tin video -QZ7TDSJgLg
# Không thể lấy thông tin video TP7dCLK3YUY
# Không thể lấy thông tin video ZuyGMVYzQyI
# Không thể lấy thông tin video ZuyGMVYzQyI
# Data gửi đi: {
#   "records": [
#     {
#       "id": "recgrOcjhoCXt0g8P",
#       "fields": {
#         "description": "Learn the difference between procrastinating and a procrastination addiction. \n\nJoin my Learning Drops newsletter (free): https://bit.ly/452S1bs\nEvery week, I distil what really works for improving results, memory, depth of understanding, and knowledge application from over a decade of coaching into bite-sized emails.\n\nLearner Type Quiz (free) - Figure out your learning strengths and weaknesses: https://bit.ly/3x6mokN\n\nLearning System Diagnostic Quiz (free) - See how the way you learn compares to top learners: https://bit.ly/3yHEqdK\n\nResearch summary on learning (free): https://icanstudy.com/report-on-learning\n\nWatch my TEDx talk on learning to learn (top 1% viewed in 2022): https://www.youtube.com/watch?v=TQXMl4GycD0\n\n\n=== Paid Training Program ===\n\nJoin my step-by-step learning skills program to improve your results: https://bit.ly/4e5jM7q\n\n(Designed for busy students and professionals aiming to achieve top results without endless studying. 77% of our students cover the same amount of study material in 30% less time within 1 month.)\n\n\n=== Timestamps ===\n\n00:00 Intro \n00:35 What\u2019s the difference?\n03:15 The real problem \n04:42 How to know: Step 1 \n05:19 How to know: Step 2\n07:12 Is it different from ADHD? \n09:07 Solution step 1 \n09:47 Solution step 2 \n11:07 Solution step 3 \n\n\n=== About Dr Justin Sung ===\n\nDr. Justin Sung is a world-renowned expert in self-regulated learning, certified teacher, research author, and former medical doctor. He has guest lectured on learning skills at Monash University for Master\u2019s and PhD students in Education and Medicine. Over the past decade, he has empowered tens of thousands of learners worldwide to dramatically improve their academic performance, learning efficiency, and motivation.\n\nInstagram: https://instagram.com/drjustinsung\nTikTok: https://tiktok.com/@drjustinsung\nFacebook: https://www.facebook.com/drjustinsung\nLinkedIn: https://www.linkedin.com/in/justin-sung/\nX: https://x.com/drjustinsung",
#         "username": "@JustinSung",
#         "published_time": "2024-04-19T05:00:18-07:00",
#         "viewCount": 318135,
#         "likeCount": 14067,
#         "subtitles_url": "https://www.youtube.com/api/timedtext?v=JssA1fkgAJY&ei=Oj8hZ_zoOYO0kucP-qjBqA8&caps=asr&opi=112496729&exp=xpo,xbt&xoaf=7&hl=en&ip=0.0.0.0&ipbits=0&expire=1730257322&sparams=ip,ipbits,expire,v,ei,caps,opi,exp,xoaf&signature=13CAB988CA397E62AB6687082E6AE57AAB8FEE9F.27467BB3F89FDFC2D20A4D63075FC6813B24BD3C&key=yt8&kind=asr&lang=en"
#       }
#     }
#   ]
# }
# Response status code: 200
# Response body: {"records":[{"id":"recgrOcjhoCXt0g8P","createdTime":"2024-10-29T19:55:45.000Z","fields":{"video_id":"JssA1fkgAJY","title":"How to Beat Procrastination (Forever)","length":815,"published_time":"2024-04-19T12:00:18.000Z","viewCount":318135,"username":"@JustinSung","description":"Learn the difference between procrastinating and a procrastination addiction. \n\nJoin my Learning Drops newsletter (free): https://bit.ly/452S1bs\nEvery week, I distil what really works for improving results, memory, depth of understanding, and knowledge application from over a decade of coaching into bite-sized emails.\n\nLearner Type Quiz (free) - Figure out your learning strengths and weaknesses: https://bit.ly/3x6mokN\n\nLearning System Diagnostic Quiz (free) - See how the way you learn compares to top learners: https://bit.ly/3yHEqdK\n\nResearch summary on learning (free): https://icanstudy.com/report-on-learning\n\nWatch my TEDx talk on learning to learn (top 1% viewed in 2022): https://www.youtube.com/watch?v=TQXMl4GycD0\n\n\n=== Paid Training Program ===\n\nJoin my step-by-step learning skills program to improve your results: https://bit.ly/4e5jM7q\n\n(Designed for busy students and professionals aiming to achieve top results without endless studying. 77% of our students cover the same amount of study material in 30% less time within 1 month.)\n\n\n=== Timestamps ===\n\n00:00 Intro \n00:35 What’s the difference?\n03:15 The real problem \n04:42 How to know: Step 1 \n05:19 How to know: Step 2\n07:12 Is it different from ADHD? \n09:07 Solution step 1 \n09:47 Solution step 2 \n11:07 Solution step 3 \n\n\n=== About Dr Justin Sung ===\n\nDr. Justin Sung is a world-renowned expert in self-regulated learning, certified teacher, research author, and former medical doctor. He has guest lectured on learning skills at Monash University for Master’s and PhD students in Education and Medicine. Over the past decade, he has empowered tens of thousands of learners worldwide to dramatically improve their academic performance, learning efficiency, and motivation.\n\nInstagram: https://instagram.com/drjustinsung\nTikTok: https://tiktok.com/@drjustinsung\nFacebook: https://www.facebook.com/drjustinsung\nLinkedIn: https://www.linkedin.com/in/justin-sung/\nX: https://x.com/drjustinsung","likeCount":14067,"subtitles_url":"https://www.youtube.com/api/timedtext?v=JssA1fkgAJY&ei=Oj8hZ_zoOYO0kucP-qjBqA8&caps=asr&opi=112496729&exp=xpo,xbt&xoaf=7&hl=en&ip=0.0.0.0&ipbits=0&expire=1730257322&sparams=ip,ipbits,expire,v,ei,caps,opi,exp,xoaf&signature=13CAB988CA397E62AB6687082E6AE57AAB8FEE9F.27467BB3F89FDFC2D20A4D63075FC6813B24BD3C&key=yt8&kind=asr&lang=en"}}]}
# Đã cập nhật record recgrOcjhoCXt0g8P
# Không thể lấy thông tin video JssA1fkgAJY
# Không thể lấy thông tin video IXKFyQZMiHE
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-65c8d361f422> in <module>
#      99
#     100 if __name__ == "__main__":
# --> 101     main()
#
# <ipython-input-5-65c8d361f422> in main()
#      89         if video_id:
#      90             # Lấy thông tin video từ YouTube API
# ---> 91             video_data = get_youtube_video_details(video_id)
#      92
#      93             if video_data.get("status"):
#
# <ipython-input-5-65c8d361f422> in get_youtube_video_details(video_id)
#      23     params = {"videoId": video_id}
#      24
# ---> 25     response = requests.get(url, headers=headers, params=params)
#      26     return response.json()
#      27
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     668
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#     672                 method,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# ~/opt/anaconda3/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
