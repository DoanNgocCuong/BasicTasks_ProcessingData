# %%
import requests
import json
import http.client
import time
from datetime import datetime, timedelta
import re

# Constants
AIRTABLE_BASE_ID = 'app7mcJMf9O8GQRal'
AIRTABLE_API_KEY = ''
YOUTUBE_TABLE = 'youtube_user'
POSTS_TABLE = 'youtube_post'
RAPIDAPI_KEY = ""

def get_youtube_users():
    """Lấy danh sách username từ bảng youtube_user"""
    url = f"https://api.airtable.com/v0/{AIRTABLE_BASE_ID}/{YOUTUBE_TABLE}"
    headers = {
        'Authorization': f'Bearer {AIRTABLE_API_KEY}',
        'Content-Type': 'application/json'
    }
    
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        data = response.json()
        return [record['fields'].get('username') for record in data.get('records', [])]
    return []

def get_existing_video_ids():
    """Lấy danh sách video_id đã tồn tại"""
    url = f"https://api.airtable.com/v0/{AIRTABLE_BASE_ID}/{POSTS_TABLE}"
    headers = {
        'Authorization': f'Bearer {AIRTABLE_API_KEY}',
        'Content-Type': 'application/json'
    }
    
    existing_ids = set()
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        data = response.json()
        existing_ids = {record['fields'].get('video_id') for record in data.get('records', [])}
    return existing_ids

def get_channel_videos(channel_id):
    """Lấy tất cả video từ một channel"""
    videos = []
    next_token = None
    
    while True:
        conn = http.client.HTTPSConnection("youtube-media-downloader.p.rapidapi.com")
        headers = {
            'x-rapidapi-key': RAPIDAPI_KEY,
            'x-rapidapi-host': "youtube-media-downloader.p.rapidapi.com"
        }
        
        url = f"/v2/channel/videos?channelId={channel_id}&type=videos&sortBy=newest"
        if next_token:
            url += f"&nextToken={next_token}"
            
        try:
            conn.request("GET", url, headers=headers)
            res = conn.getresponse()
            data = json.loads(res.read().decode("utf-8"))
            
            if not data.get("status"):
                print(f"Lỗi khi lấy video từ channel {channel_id}: {data.get('errorId')}")
                break
                
            if "items" in data:
                videos.extend(data["items"])
                
            next_token = data.get("nextToken")
            if not next_token:
                break
                
            time.sleep(1)  # Tránh rate limit
            
        except Exception as e:
            print(f"Lỗi: {str(e)}")
            break
        finally:
            conn.close()
            
    return videos

def convert_length_to_time(length_text):
    """Convert length text (e.g. "10:28") to seconds"""
    if not length_text:
        return 0
        
    parts = length_text.split(':')
    
    if len(parts) == 2:  # mm:ss
        minutes = int(parts[0])
        seconds = int(parts[1])
        return minutes * 60 + seconds
    elif len(parts) == 3:  # hh:mm:ss
        hours = int(parts[0])
        minutes = int(parts[1])
        seconds = int(parts[2])
        return hours * 3600 + minutes * 60 + seconds
        
    return 0

def extract_view_count(view_text):
    """Extract number from view count text (e.g. "7,138 views")"""
    if not view_text:
        return 0
    number = re.sub(r'[^0-9,]', '', view_text)
    return int(number.replace(',', ''))

def convert_published_time(time_text):
    """Convert relative time to actual date"""
    now = datetime.now()
    
    if not time_text:
        return now.strftime('%Y-%m-%d')
        
    match = re.search(r'(\d+)\s*(hour|day|week|month|year)s?\s*ago', time_text.lower())
    if not match:
        return now.strftime('%Y-%m-%d')
        
    number = int(match.group(1))
    unit = match.group(2)
    
    if unit == 'hour':
        date = now - timedelta(hours=number)
    elif unit == 'day':
        date = now - timedelta(days=number)
    elif unit == 'week':
        date = now - timedelta(weeks=number)
    elif unit == 'month':
        date = now - timedelta(days=number*30)  # approximate
    elif unit == 'year':
        date = now - timedelta(days=number*365)  # approximate
    else:
        return now.strftime('%Y-%m-%d')
        
    return date.strftime('%Y-%m-%d')

def main():
    # Lấy danh sách username
    usernames = get_youtube_users()
    print(f"Tìm thấy {len(usernames)} users")
    
    # Lấy danh sách video_id đã tồn tại
    existing_videos = get_existing_video_ids()
    print(f"Đã có {len(existing_videos)} videos trong database")
    
    # Xử lý từng username
    for username in usernames:
        print(f"\nĐang xử lý channel: {username}")
        videos = get_channel_videos(username)
        
        # Lọc các video chưa tồn tại
        new_videos = [v for v in videos if v['id'] not in existing_videos]
        print(f"Tìm thấy {len(new_videos)} videos mới")
        
        # Thêm các video mới vào Airtable
        headers = {
            'Authorization': f'Bearer {AIRTABLE_API_KEY}',
            'Content-Type': 'application/json'
        }
        
        for video in new_videos:
            data = {
                "fields": {
                    "video_id": video['id'],
                    "title": video['title'],
                    "length": convert_length_to_time(video.get('lengthText', '')),
                    "viewCount": extract_view_count(video.get('viewCountText', '')),
                    "published_time": convert_published_time(video.get('publishedTimeText', '')),
                    "username": username
                }
            }
            
            response = requests.post(
                f"https://api.airtable.com/v0/{AIRTABLE_BASE_ID}/{POSTS_TABLE}",
                headers=headers,
                json=data
            )
            
            if response.status_code == 200:
                print(f"✓ Đã thêm video: {video['title']}")
            else:
                print(f"✗ Lỗi khi thêm video {video['title']}: {response.text}")

if __name__ == "__main__":
    main()
# Out:
# Tìm thấy 4 users
# Đã có 100 videos trong database
#
# Đang xử lý channel: POCEnglish
# Tìm thấy 138 videos mới
# ✓ Đã thêm video: Learn English Idioms and Vocabulary with Horror Movies!
# ✓ Đã thêm video: Formal or Informal English? Learn the Right Words
# ✓ Đã thêm video: Business English Vocabulary You Need to Know
# ✓ Đã thêm video: DO NOT say "I'm Sorry"! Apologize PROPERLY in English!
# ✓ Đã thêm video: I Hit 3M Subs and I'm Giving Back 50% Off My English Course!
# ✓ Đã thêm video: Speak English at the Doctor’s Office with Confidence
# ✓ Đã thêm video: 25 Must-Know English Idioms for Fluent Conversation!
# ✓ Đã thêm video: How Many of These 10 English Words Do You Know?
# ✓ Đã thêm video: Stop Overusing Simple English Words!
# ✓ Đã thêm video: English Learning Tips & Challenges: Stories from International Students
# ✓ Đã thêm video: English Vocabulary: Travel and Adventure
# ✓ Đã thêm video: Confusing English Phrasal Verbs? Not Anymore!
# ✓ Đã thêm video: What’s your English level? Take this test!
# ✓ Đã thêm video: No More Simple English Words! Synonyms Of 10 Common English Words
# ✓ Đã thêm video: How to Learn English Vocabulary and Improve Speaking
# ✓ Đã thêm video: 15 Most Common English Grammar Mistakes
# ✓ Đã thêm video: 10 English Phrasal Verbs For Speaking!
# ✓ Đã thêm video: Level up your English vocabulary by learning these synonyms!
# ✓ Đã thêm video: 20+1 English Phrasal Verbs You MUST Know!
# ✓ Đã thêm video: English Food Vocabulary
# ✓ Đã thêm video: Level Up Your English Vocabulary! Learn these 10 English common words synonyms!
# ✓ Đã thêm video: Speak English At The Hotel!🏨 Hotel vocabulary + expressions
# ✓ Đã thêm video: Holiday Vocabulary & Idioms in English!
# ✓ Đã thêm video: Music vocabulary in English: Expressions & collocations + practical examples 🎤🎧🎵
# ✓ Đã thêm video: English Idioms & Collocations: Behavior & Emotions!
# ✓ Đã thêm video: 30 Must-Know English Idioms for Fluent Conversation!
# ✓ Đã thêm video: American English & British English Slang and Idioms!
# ✓ Đã thêm video: Describing Cities & Places In English!
# ✓ Đã thêm video: Let's Talk Money! (English Vocabulary & Idioms)
# ✓ Đã thêm video: English Idioms & Collocations: Relationships! + With practical examples!
# ✓ Đã thêm video: How to describe your house & neighborhood in English?
# ✓ Đã thêm video: Advanced English Phrases for Everyday Speaking!
# ✓ Đã thêm video: Speak English At The Restaurant!
# ✓ Đã thêm video: Business English Vocabulary, Idioms & phrases | A complete list + examples
# ✓ Đã thêm video: Formal English Phrases For Everyday Conversation!
# ✓ Đã thêm video: Airport vocabulary | Speak English at the airport! 🛫
# ✓ Đã thêm video: What happens in my General English Course?
# ✓ Đã thêm video: Advanced Personality Adjectives In English!
# ✓ Đã thêm video: Idioms with colors in English | A complete list of color idioms + example
# ✓ Đã thêm video: 30 Must-Know Idioms for Fluent English Conversation
# ✓ Đã thêm video: When to Use 'The' in English: 6 Rules & 3 Common Mistakes
# ✓ Đã thêm video: 10 Common English Speaking Mistakes to Avoid!
# ✓ Đã thêm video: Level Up Your English Vocabulary (Stop Using Simple Words)
# ✓ Đã thêm video: Mastering IELTS Writing Task 1: How to Tackle Bar Charts
# ✓ Đã thêm video: My 2-Day Sale is Here! Start learning English today!
# ✓ Đã thêm video: Learn Advanced Weather Vocabulary | #EnglishVocabulary Explained!
# ✓ Đã thêm video: Small Talk 101: How to Start and Keep a Conversation in English
# ✓ Đã thêm video: How I Got Academic IELTS 9.0 (overall!)
# ✓ Đã thêm video: What’s your English level? Take this test (C1/C2)
# ✓ Đã thêm video: What’s your English level? Take this test (B1/B2)
# ✓ Đã thêm video: What’s your English level? Take this test (A1/A2)
# ✓ Đã thêm video: 8 English Phrasal Verbs With "UP"
# ✓ Đã thêm video: English Pronunciation practice | Follow these tips step by step
# ✓ Đã thêm video: English Speaking: Shopping For Clothes
# ✓ Đã thêm video: 5 Advanced English Idioms! (With Examples)
# ✓ Đã thêm video: Are You Making These 10 Mistakes In English Grammar?
# ✓ Đã thêm video: Speak English With Confidence (Job & University interview)
# ✓ Đã thêm video: Stop Saying "I want" in English!
# ✓ Đã thêm video: Stop Saying "I like" in English (Speaking lesson)
# ✓ Đã thêm video: English Speaking Lesson (Making Requests In English!)
# ✓ Đã thêm video: English Speaking Lesson (asking for & giving advice)
# ✓ Đã thêm video: What’s your English level? Take this test!
# ✓ Đã thêm video: English punctuation rules (Comma, Period, Colon, Semicolon)
# ✓ Đã thêm video: What are other words for but( synonyms for but) ? + example
# ✓ Đã thêm video: Formal and Informal words in English + examples (Part 4)
# ✓ Đã thêm video: How To Improve Your English Speaking Skill (Top Tips!)
# ✓ Đã thêm video: What is intonation in English? How many types does it have?
# ✓ Đã thêm video: The most common English slang words you should know about
# ✓ Đã thêm video: Speak English Over The Phone!
# ✓ Đã thêm video: 10 Tools To Practice Your English (For Free!)
# ✓ Đã thêm video: A Preview Of My English Courses (+ $20 discount code!)
# ✓ Đã thêm video: How To Practice Your English Speaking Skill
# ✓ Đã thêm video: Problem solving phrases  | Talking about problems in English
# ✓ Đã thêm video: The most common health idioms | idioms for healthy lifestyle (with example)
# ✓ Đã thêm video: 10 Commonly Mispronounced Words In The English Language
# ✓ Đã thêm video: Health and illness vocabulary | Talking about health problems + example
# ✓ Đã thêm video: English Grammar: Don't Make These Grammatical Mistakes!
# ✓ Đã thêm video: 10 Fun & Useful English Idioms! (With Examples)
# ✓ Đã thêm video: Secret Revealed! Best Way To Learn English Fast!
# ✓ Đã thêm video: How To Write An Informal Email In English (Easily!)
# ✓ Đã thêm video: Goodbye Grammar! 3 Steps To Learn English Grammar
# ✓ Đã thêm video: 10 English Idioms You Must Know! (With Examples)
# ✓ Đã thêm video: 5 Very Common Grammatical Mistakes In English
# ✓ Đã thêm video: Alternatives to  say | synonyms of say
# ✓ Đã thêm video: Stop using simple words in English!
# ✓ Đã thêm video: Formal VS Informal English Vocabulary (Part 3)
# ✓ Đã thêm video: Improve Your English Vocabulary (Food Idioms!)
# ✓ Đã thêm video: 5 Simple English Mistakes Even Native Speakers Make!
# ✓ Đã thêm video: English Vocabulary: Confusing Words! (Part 2)
# ✓ Đã thêm video: Asking For & Giving Directions In English!
# ✓ Đã thêm video: English Vocabulary (Confusing Words)!
# ✓ Đã thêm video: English Writing Masterclass (Improve Your Writing!)
# ✓ Đã thêm video: Improve Your English Listening Skill With Podcasts!
# ✓ Đã thêm video: Formal VS Informal English Vocabulary
# ✓ Đã thêm video: Level Up Your English Vocabulary (Stop Using Simple Words)
# ✓ Đã thêm video: Are You Making These Mistakes In English Grammar?
# ✓ Đã thêm video: Business English Vocabulary! How to use them?
# ✓ Đã thêm video: Improve Your English Pronunciation & Accent!
# ✓ Đã thêm video: How to improve English speaking? | Follow these tips!
# ✓ Đã thêm video: Talking about TIME in English using the verb TAKE
# ✓ Đã thêm video: 15 English Phrasal Verbs & Vocabulary About SPORTS
# ✓ Đã thêm video: Stop synonyms in English (formal & informal) with example!
# ✓ Đã thêm video: English Newspaper Vocabulary
# ✓ Đã thêm video: Secrets To Learn English Fast (Best Method)
# ✓ Đã thêm video: Improve Your English Vocabulary (Stop Using Simple Words!)
# ✓ Đã thêm video: English Pronunciation Lesson (Phonetics)
# ✓ Đã thêm video: 11 English Phrasal Verbs & Vocabulary About Relationships!
# ✓ Đã thêm video: English Conversations & Vocabulary About Clothes
# ✓ Đã thêm video: Stop Saying "I AGREE"! In English Language!
# ✓ Đã thêm video: 5 Unusual English Idioms Related To Transport!
# ✓ Đã thêm video: 9 English Phrasal Verbs To Talk About Plans & Decisions
# ✓ Đã thêm video: Stop Saying "I THINK"! In English Language!
# ✓ Đã thêm video: 4 English Idioms With History (+Milan City Tour!)
# ✓ Đã thêm video: How To Speak English Fast And Understand Native Speakers
# ✓ Đã thêm video: 20 Words To Talk About Food In English
# ✓ Đã thêm video: How To Learn English With Movies (+Movie Vocabulary)
# ✓ Đã thêm video: English Grammar Lesson (Confusing Prepositions)
# ✓ Đã thêm video: Forget Words When Speaking English? Here Is Why!
# ✓ Đã thêm video: 10 American English Pronunciation Tips
# ✓ Đã thêm video: 10 English Phrasal Verbs You Need To Know About Travelling
# ✓ Đã thêm video: 10 Most Common English Grammar Mistakes || Basic English Grammar
# ✓ Đã thêm video: English pronunciation: 12 contractions you MUST learn!
# ✓ Đã thêm video: Learn English vocabulary || Nature idioms
# ✓ Đã thêm video: 8 phrasal verbs in English to talk about studying and exams (super useful)
# ✓ Đã thêm video: 5 English idioms about fashion and clothing || English vocabulary in Milan's fashion district!
# ✓ Đã thêm video: English grammar: 10 Adjectives and adverbs with the same form!
# ✓ Đã thêm video: 20 adjectives to describe feelings!
# ✓ Đã thêm video: Adjectives or adverbs?? Let's make it clear!
# ✓ Đã thêm video: 10 words to talk about injuries in English language
# ✓ Đã thêm video: 5 very useful phrasal verbs to talk about arguments and disagreeing!
# ✓ Đã thêm video: 8 Travel idioms in English language and a trip to Venice! Part 2
# ✓ Đã thêm video: 5 English idioms about travelling, and a trip to Venice, Italy! Part 1
# ✓ Đã thêm video: 5 Common English grammar mistakes for lower intermediate level
# ✓ Đã thêm video: 15 English personality adjectives| How to ask and talk about someone's personality?
# ✓ Đã thêm video: All VS Every! English grammar tips: What are the differences and how to use them in a sentence!
# ✓ Đã thêm video: 5 common grammar mistakes with tenses in English language and how to avoid them!
# ✓ Đã thêm video: 9 English idioms with the word "Age"
# ✓ Đã thêm video: 6 phrasal verbs to talk about problems & solutions!
#
# Đang xử lý channel: ProductivityGame
# Tìm thấy 199 videos mới
# ✓ Đã thêm video: LEADERSHIP STRATEGY and TACTICS by Jocko Willink | Core Message
# ✓ Đã thêm video: THE 6 TYPES OF WORKING GENIUS by Patrick Lencioni | Core Message
# ✓ Đã thêm video: SURROUNDED BY IDIOTS by Thomas Erikson | Core Message
# ✓ Đã thêm video: SUPERCOMMUNICATORS by Charles Duhigg | Core Message
# ✓ Đã thêm video: THE SCOUT MINDSET by Julia Galef | Core Message
# ✓ Đã thêm video: NOISE by Daniel Kahneman | Core Message
# ✓ Đã thêm video: SLOW PRODUCTIVITY by Cal Newport | Core Message
# ✓ Đã thêm video: Optimize your workdays: MANAGE YOUR DAY-TO-DAY by Jocelyn Glei | Core Message
# ✓ Đã thêm video: THE MOTIVATION MANIFESTO by Brendon Burchard | Core Message
# ✓ Đã thêm video: THE ENERGY PARADOX by Dr. Steven Gundry | Core Message
# ✓ Đã thêm video: How Will You Measure Your Life? by Clayton Christensen | Core Message
# ✓ Đã thêm video: Unlock your purpose: IKIGAI by Héctor García and Francesc Miralles | Core Message
# ✓ Đã thêm video: Make work enjoyable: FEEL-GOOD PRODUCTIVITY by Ali Abdaal | Core Message
# ✓ Đã thêm video: 3 Essential Steps to Master Any Change: MASTER OF CHANGE by Brad Stulberg | Core Message
# ✓ Đã thêm video: THE FIRST RULE OF MASTERY by Michael Gervais | Core Message
# ✓ Đã thêm video: HIDDEN POTENTIAL by Adam Grant | Core Message
# ✓ Đã thêm video: THINK FASTER, TALK SMARTER by Matt Abrahams | Core Message
# ✓ Đã thêm video: MAGIC WORDS by Jonah Berger | Core Message
# ✓ Đã thêm video: THE PRODUCTIVITY PROJECT by Chris Bailey | Animated Core Message
# ✓ Đã thêm video: 100 WAYS TO MOTIVATE YOURSELF by Steve Chandler | Core Message
# ✓ Đã thêm video: How to stop procrastinating | SOLVING THE PROCRASTINATION PUZZLE by Timothy Pychyl | Core Message
# ✓ Đã thêm video: Learn to lead: THE 21 IRREFUTABLE LAWS OF LEADERSHIP by John Maxwell | Core Message
# ✓ Đã thêm video: Infinite mindset = sustained performance | THE INFINITE GAME by Simon Sinek | Core Message
# ✓ Đã thêm video: How to defeat your inner enemy: COMING ALIVE by Barry Michels & Phil Stutz | Core Message
# ✓ Đã thêm video: This book will change your life: THE MOUNTAIN IS YOU by Brianna Wiest | Core Message
# ✓ Đã thêm video: Design your rich life: I WILL TEACH YOU TO BE RICH by Ramit Sethi | Core Message
# ✓ Đã thêm video: THE MILLIONAIRE NEXT DOOR by Thomas Stanley and William Danko | Core Message
# ✓ Đã thêm video: TO-DO LIST FORMULA by Damon Zahariades | Core Message
# ✓ Đã thêm video: OUTLIVE by Peter Attia, MD | Core Message
# ✓ Đã thêm video: THE CREATIVE ACT by Rick Rubin | Core Message
# ✓ Đã thêm video: TRACTION by Gino Wickman | Core Message
# ✓ Đã thêm video: STOLEN FOCUS by Johann Hari | Core Message
# ✓ Đã thêm video: THE EXPECTATION EFFECT by David Robson | Core Message
# ✓ Đã thêm video: STORYWORTHY by Matthew Dicks | Core Message
# ✓ Đã thêm video: REJECTION PROOF by Jia Jiang | Core Message
# ✓ Đã thêm video: NEVER FINISHED by David Goggins | Core Message
# ✓ Đã thêm video: THE UNFAIR ADVANTAGE by Ash Ali and Hasan Kubba | Core Message
# ✓ Đã thêm video: THE 80/20 PRINCIPLE by Richard Koch | Core Message
# ✓ Đã thêm video: THE LONG GAME by Dorie Clark | Core Message
# ✓ Đã thêm video: HYPERFOCUS by Chris Bailey | Core Message
# ✓ Đã thêm video: THE ALTER EGO EFFECT by Todd Herman | Core Message
# ✓ Đã thêm video: ON WRITING WELL by William Zinsser | Core Message
# ✓ Đã thêm video: THE ART OF THINKING CLEARLY by Rolf Dobelli | Core Message
# ✓ Đã thêm video: BUILDING A SECOND BRAIN by Tiago Forte | Core Message
# ✓ Đã thêm video: STOP OVERTHINKING by Nick Trenton | Core Message
# ✓ Đã thêm video: THE POWER OF ONE MORE by Ed Mylett | Core Message
# ✓ Đã thêm video: ATLAS OF THE HEART by Brené Brown | Core Message
# ✓ Đã thêm video: THE CONFIDENT MIND by Dr. Nate Zinsser | Core Message
# ✓ Đã thêm video: JUST KEEP BUYING by Nick Maggiulli | Core Message
# ✓ Đã thêm video: ORGANIZE TOMORROW TODAY by Jason Selk & Tom Bartow | Core Message
# ✓ Đã thêm video: COMPANY OF ONE by Paul Jarvis | Core Message
# ✓ Đã thêm video: DAVID AND GOLIATH by Malcolm Gladwell | Core Message
# ✓ Đã thêm video: DOPAMINE NATION by Anna Lembke | Core Message
# ✓ Đã thêm video: THE POWER OF REGRET by Daniel Pink | Core Message
# ✓ Đã thêm video: THE CULTURE CODE by Daniel Coyle | Core Message
# ✓ Đã thêm video: THE 48 LAWS OF POWER by Robert Greene | Core Message
# ✓ Đã thêm video: TRIGGERS by Marshall Goldsmith | Core Message
# ✓ Đã thêm video: YOUR BEST YEAR EVER by Michael Hyatt | Core Message
# ✓ Đã thêm video: DISCIPLINE = FREEDOM by Jocko Willink | Core Message
# ✓ Đã thêm video: THE EXTENDED MIND by Annie Murphy Paul | Core Message
# ✓ Đã thêm video: FOUR THOUSAND WEEKS by Oliver Burkeman | Core Message
# ✓ Đã thêm video: FINISH WHAT YOU START by Peter Hollins | Core Message
# ✓ Đã thêm video: PROFIT FIRST by Mike Michalowicz | Core Message
# ✓ Đã thêm video: INVENT & WANDER by Jeff Bezos | Core Message
# ✓ Đã thêm video: THE DAILY STOIC by Ryan Holiday | Core Message
# ✓ Đã thêm video: Secrets to Pure Performance: THE MINDFUL ATHLETE by George Mumford | Core Message
# ✓ Đã thêm video: WINNING by Tim Grover | Core Message
# ✓ Đã thêm video: DECODING GREATNESS by Ron Friedman | Core Message
# ✓ Đã thêm video: THE ART OF SAYING NO by Damon Zahariades | Core Message
# ✓ Đã thêm video: HOW TO TALK TO ANYONE by Leil Lowndes | Core Message
# ✓ Đã thêm video: How to be creative: INSIDE THE BOX by Drew Boyd and Jacob Goldenberg | Core Message
# ✓ Đã thêm video: THE PRACTICE by Seth Godin | Core Message
# ✓ Đã thêm video: THINK AGAIN by Adam Grant | Core Message
# ✓ Đã thêm video: HOW TO DECIDE by Annie Duke | Core Message
# ✓ Đã thêm video: THE GREAT MENTAL MODELS by Shane Parrish | Core Message
# ✓ Đã thêm video: ANTIFRAGILE by Nassim Taleb | Core Message
# ✓ Đã thêm video: THE PSYCHOLOGY OF MONEY by Morgan Housel | Core Message
# ✓ Đã thêm video: RICH DAD POOR DAD by Robert Kiyosaki | Core Message
# ✓ Đã thêm video: THE 5 AM CLUB by Robin Sharma | Core Message
# ✓ Đã thêm video: THE FOUR AGREEMENTS by Don Miguel Ruiz | Core Message
# ✓ Đã thêm video: HOW I BUILT THIS by Guy Raz | Core Message
# ✓ Đã thêm video: TINY HABITS by BJ Fogg | Core Message
# ✓ Đã thêm video: THE POWER OF HABIT by Charles Duhigg | Core Message
# ✓ Đã thêm video: THE TOOLS by Barry Michels and Phil Stutz | Core Message
# ✓ Đã thêm video: THE CHAMPION'S MIND by Jim Afremow | Core Message
# ✓ Đã thêm video: Optimize your breathing: BREATH by James Nestor | Core Message
# ✓ Đã thêm video: HELL YEAH OR NO by Derek Sivers | Core Message
# ✓ Đã thêm video: THINKING IN BETS by Annie Duke | Core Message
# ✓ Đã thêm video: LIMITLESS by Jim Kwik | Core Message
# ✓ Đã thêm video: PSYCHO-CYBERNETICS by Maxwell Maltz | Core Message
# ✓ Đã thêm video: EXACTLY WHAT TO SAY by Phil Jones | Core Message
# ✓ Đã thêm video: THE OBSTACLE IS THE WAY by Ryan Holiday | Core Message
# ✓ Đã thêm video: 13 THINGS MENTALLY STRONG PEOPLE DON'T DO by Amy Morin | Core Message
# ✓ Đã thêm video: OWN THE DAY, OWN YOUR LIFE by Aubrey Marcus | Core Message
# ✓ Đã thêm video: AWAKEN THE GIANT WITHIN by Tony Robbins | Core Message
# ✓ Đã thêm video: HOW TO STOP WORRYING AND START LIVING by Dale Carnegie | Core Message
# ✓ Đã thêm video: $100 STARTUP & 100 SIDE HUSTLES by Chris Guillebeau | Core Message
# ✓ Đã thêm video: MINI HABITS by Stephen Guise | Core Message
# ✓ Đã thêm video: INDISTRACTABLE by Nir Eyal | Core Message
# ✓ Đã thêm video: MAKE TIME by Jake Knapp and John Zeratsky | Core Message
# ✓ Đã thêm video: THE ART OF LEARNING by Josh Waitzkin | Core Message
# ✓ Đã thêm video: ULTRALEARNING by Scott Young | Core Message
# ✓ Đã thêm video: RANGE by David Epstein | Core Message
# ✓ Đã thêm video: MEDITATIONS by Marcus Aurelius | Core Message
# ✓ Đã thêm video: THE 5 ELEMENTS OF EFFECTIVE THINKING by Edward Burger & Michael Starbird
# ✓ Đã thêm video: SWITCH by Chip Heath and Dan Heath | Animated Core Message
# ✓ Đã thêm video: GOOD TO GREAT by Jim Collins | Core Message
# ✓ Đã thêm video: Negotiation Principles: GETTING TO YES by Roger Fisher and William Ury | Core Message
# ✓ Đã thêm video: THE 12 WEEK YEAR by B. Moran and M. Lennington | Animated Core Message
# ✓ Đã thêm video: MAN'S SEARCH FOR MEANING by Viktor Frankl | Core Message
# ✓ Đã thêm video: CAN'T HURT ME by David Goggins | Core Message
# ✓ Đã thêm video: THE MIRACLE MORNING by Hal Elrod | Core Message
# ✓ Đã thêm video: THE BULLET JOURNAL METHOD by Ryder Carroll | Core Message
# ✓ Đã thêm video: Master Marketing: BUILDING A STORYBRAND by Donald Miller | Book Summary Core Message
# ✓ Đã thêm video: START WITH WHY + FIND YOUR WHY by Simon Sinek | Core Message
# ✓ Đã thêm video: THE 5 DYSFUNCTIONS OF A TEAM by Patrick Lencioni | Core Message
# ✓ Đã thêm video: CRUCIAL CONVERSATIONS by K. Patterson, J. Grenny, R. Mcmillan, and A. Switzler | Core Message
# ✓ Đã thêm video: WHY WE SLEEP by Matthew Walker PhD | Core Message
# ✓ Đã thêm video: UNLIMITED MEMORY by Kevin Horsley | Core Message
# ✓ Đã thêm video: The 4 Fs of Flow | FLOW by Mihaly Csikszentmihalyi | Core Message
# ✓ Đã thêm video: THINKING, FAST AND SLOW by Daniel Kahneman | Core Message
# ✓ Đã thêm video: EMOTIONAL AGILITY by Susan David | Core Message
# ✓ Đã thêm video: THE WAR OF ART by Steven Pressfield | Core Message
# ✓ Đã thêm video: THE TALENT CODE by Daniel Coyle | Core Message
# ✓ Đã thêm video: THE COACHING HABIT by Michael Bungay Stanier | Core Message
# ✓ Đã thêm video: How to Study: MAKE IT STICK by P. Brown, M.McDaniel & H.Roediger III | Core Message
# ✓ Đã thêm video: WHEN by Daniel Pink | Core Message
# ✓ Đã thêm video: TRIBE OF MENTORS by Tim Ferriss | Core Message
# ✓ Đã thêm video: PERFORMING UNDER PRESSURE by Hendrie Weisinger and JP Pawliw-Fry | Core Message
# ✓ Đã thêm video: MEASURE WHAT MATTERS by John Doerr | Core Message
# ✓ Đã thêm video: HOOKED by Nir Eyal | Core Message
# ✓ Đã thêm video: THE E-MYTH REVISITED by Michael Gerber | Core Message
# ✓ Đã thêm video: Zero to One by Peter Thiel - BONUS INSIGHT
# ✓ Đã thêm video: ZERO TO ONE by Peter Thiel | Core Message
# ✓ Đã thêm video: Barking Up the Wrong Tree by Eric Barker | BONUS INSIGHT
# ✓ Đã thêm video: BARKING UP THE WRONG TREE by Eric Barker | Core Message
# ✓ Đã thêm video: DESIGNING YOUR LIFE by Dave Evans and Bill Burnett | Core Message
# ✓ Đã thêm video: How to Negotiate: NEVER SPLIT THE DIFFERENCE by Chris Voss | Core Message
# ✓ Đã thêm video: How to Win Friends and Influence People by Dale Carnegie | BONUS INSIGHTS
# ✓ Đã thêm video: HOW TO WIN FRIENDS AND INFLUENCE PEOPLE by Dale Carnegie | Animated Core Message
# ✓ Đã thêm video: THE CHARISMA MYTH by Olivia Fox Cabane | Animated Core Message
# ✓ Đã thêm video: 12 RULES FOR LIFE by Jordan Peterson | Animated Core Message
# ✓ Đã thêm video: MINDSET by Carol Dweck | Animated Core Message
# ✓ Đã thêm video: YOUR BRAIN AT WORK by David Rock | Animated Core Message
# ✓ Đã thêm video: Innovation 101: COMPETING AGAINST LUCK by Clayton Christensen | Animated Core Message
# ✓ Đã thêm video: REWORK by Jason Fried | Animated Core Message
# ✓ Đã thêm video: PRINCIPLES by Ray Dalio | Animated Core Message
# ✓ Đã thêm video: DECISIVE by Chip and Dan Heath | Animated Core Message
# ✓ Đã thêm video: MASTERY by Robert Greene | Animated Core Message
# ✓ Đã thêm video: DRIVE by Daniel Pink | Animated Core Message
# ✓ Đã thêm video: MADE TO STICK by Chip Heath and Dan Heath | Animated Core Message
# ✓ Đã thêm video: Make timeless products: PERENNIAL SELLER by Ryan Holiday
# ✓ Đã thêm video: TO SELL IS HUMAN by Daniel Pink
# ✓ Đã thêm video: MEASURE YOUR FOCUS | Productivity Game Challenge
# ✓ Đã thêm video: Morning Motivation: MORNING W.O.O.P. CHALLENGE
# ✓ Đã thêm video: The New Science of Motivation: RETHINKING POSITIVE THINKING by G.Oettingen
# ✓ Đã thêm video: Stop Procrastinating: EAT THAT FROG! by Brian Tracy
# ✓ Đã thêm video: Make the competition irrelevant: BLUE OCEAN STRATEGY by W.C. Kim and R. Mauborgne
# ✓ Đã thêm video: Validate your business idea: THE LEAN STARTUP by Eric Ries
# ✓ Đã thêm video: The 5 parts to every business: THE PERSONAL MBA by Josh Kaufman
# ✓ Đã thêm video: The Kaizen Way: ONE SMALL STEP CAN CHANGE YOUR LIFE by Robert Maurer
# ✓ Đã thêm video: Power of a Positive "No" | Productivity Principle
# ✓ Đã thêm video: Find Your Core Drive: YOUR ONE WORD by Evan Carmichael
# ✓ Đã thêm video: How to batch your tasks | ANIMATED PRODUCTIVITY PRINCIPLE
# ✓ Đã thêm video: Get confident: 10-MINUTE MENTAL TOUGHNESS by Dr. Jason Selk
# ✓ Đã thêm video: Spark learning and creativity: SPARK by Dr. John Ratey
# ✓ Đã thêm video: The Habit of Top Professionals: THE CHECKLIST MANIFESTO by Dr. Atul Gawande
# ✓ Đã thêm video: How to Build Habits & Execute Effortlessly
# ✓ Đã thêm video: Get yourself to take action: THE WILLPOWER INSTINCT by Kelly McGonigal Ph.D
# ✓ Đã thêm video: Know when to quit OR persevere: THE DIP by Seth Godin
# ✓ Đã thêm video: Stress-free productivity: GETTING THINGS DONE by David Allen
# ✓ Đã thêm video: Two Laws of Productivity: THE 4-HOUR WORKWEEK by Tim Ferriss
# ✓ Đã thêm video: Peak performance state: THE RISE OF SUPERMAN by Steven Kotler
# ✓ Đã thêm video: The one question to ask yourself: THE ONE THING by Gary Keller
# ✓ Đã thêm video: How to Innovate: LITTLE BETS by Peter Sims
# ✓ Đã thêm video: Daily Consistency = Massive Results: THE COMPOUND EFFECT by Darren Hardy | Core Message
# ✓ Đã thêm video: Happiness = Performance: THE HAPPINESS ADVANTAGE by Shawn Achor
# ✓ Đã thêm video: Sustain Your Creativity: THE ACCIDENTAL CREATIVE by Todd Henry | Core Message
# ✓ Đã thêm video: The 3 ways to silence your ego: EGO IS THE ENEMY by Ryan Holiday
# ✓ Đã thêm video: How to Master Anything: PEAK by Anders Ericsson | Core Message
# ✓ Đã thêm video: Take complete ownership: EXTREME OWNERSHIP by Jocko Willink and Leif Babin
# ✓ Đã thêm video: GRIT by Angela Duckworth | Animated CORE Message
# ✓ Đã thêm video: Scratch your own itch: ANYTHING YOU WANT by Derek Sivers
# ✓ Đã thêm video: Learning How to Learn: A MIND FOR NUMBERS by Barbara Oakley | Core Message
# ✓ Đã thêm video: SPRINT by Jake Knapp, John Zeratsky, Braden Kowitz | Animated Summary
# ✓ Đã thêm video: Why Meditation is Productive: 10% HAPPIER by Dan Harris | Core Message
# ✓ Đã thêm video: Stress enhances performance: THE UPSIDE OF STRESS by Kelly McGonigal
# ✓ Đã thêm video: Learning how to Learn: THE 4-HOUR CHEF by Tim Ferriss | ANIMATED CORE MESSAGE
# ✓ Đã thêm video: Win the career lottery: BORN FOR THIS by Chris Guillebeau
# ✓ Đã thêm video: The power of choice: SMARTER FASTER BETTER by Charles Duhigg
# ✓ Đã thêm video: Goals vs. Systems: HOW TO FAIL AND STILL WIN BIG by Scott Adams
# ✓ Đã thêm video: ARE YOU FULLY CHARGED? by Tom Rath | ANIMATED CORE MESSAGE
# ✓ Đã thêm video: #ASKGARYVEE by Gary Vaynerchuk | ANIMATED CORE MESSAGE
# ✓ Đã thêm video: BETTER THAN BEFORE by Gretchen Rubin | ANIMATED CORE MESSAGE
# ✓ Đã thêm video: ORIGINALS by Adam Grant | ANIMATED BOOK REVIEW
# ✓ Đã thêm video: SUPERBETTER by Jane McGonigal | Animated CORE Message
# ✓ Đã thêm video: HOW TO HAVE A GOOD DAY by Caroline Webb | Animated Summary
# ✓ Đã thêm video: PRESENCE: Optimizing Mental Performance
# ✓ Đã thêm video: SCRUM: Twice the Work, Half the Time
#
# Đang xử lý channel: kinanguyen04
# Lỗi khi lấy video từ channel kinanguyen04: ChannelNotFound
# Tìm thấy 0 videos mới
#
# Đang xử lý channel: JustinSung
# Tìm thấy 119 videos mới
# ✓ Đã thêm video: Give me 14 minutes, And I'll Turn You Into An Academic Weapon
# ✓ Đã thêm video: My Honest Advice to Students Who Are Falling Behind
# ✓ Đã thêm video: You’re Not Dumb: How to Mindmap as a Beginner
# ✓ Đã thêm video: How to Remember Everything You Read
# ✓ Đã thêm video: How to Force Your Brain To Be Motivated (when you don’t feel like it)
# ✓ Đã thêm video: The Ultimate Guide to The Perfect Mindmap (6-Step Checklist)
# ✓ Đã thêm video: 5 Dimensions of Learning Every Student MUST Master
# ✓ Đã thêm video: 3 Levels of Mind Maps Every Student MUST Master
# ✓ Đã thêm video: 6 Levels of Thinking Every Student MUST Master
# ✓ Đã thêm video: How to Learn Any Skill Quickly (and Forever)
# ✓ Đã thêm video: How to Force Your Brain to Study (when you don't feel like it)
# ✓ Đã thêm video: How to Pick Your Perfect Career (part 2)
# ✓ Đã thêm video: How to Pick Your Perfect Career (The Ultimate Guide) - Part 1
# ✓ Đã thêm video: How to Beat Procrastination (Forever)
# ✓ Đã thêm video: How I Would Study in Med School (If I Could Start Over)
# ✓ Đã thêm video: How the Top 0.1% Learn in Lectures
# ✓ Đã thêm video: Become a Top 0.1% Student by Avoiding This
# ✓ Đã thêm video: Why Learning Fast Leads to Bad Grades
# ✓ Đã thêm video: What I Learned after 5000 Hours of Mind Mapping
# ✓ Đã thêm video: This One Mistake Made his Mindmap Useless
# ✓ Đã thêm video: Software Engineer gets Private Coaching
# ✓ Đã thêm video: What I Learned After 5000 Hours of Revision
# ✓ Đã thêm video: HYPER EFFICIENT STUDY WITH ME | Doctor, Learning coach, Flowmodoro, White noise, Fireplace sounds
# ✓ Đã thêm video: How to Study With Me (Instructions)
# ✓ Đã thêm video: How to Finish 6 Months of Study in 72 Hours
# ✓ Đã thêm video: How to Have an Academic Comeback in 2024
# ✓ Đã thêm video: How I UPGRADE the Most Popular Study Techniques
# ✓ Đã thêm video: Ultimate Study Technique Tier List (Learning Coach Edition)
# ✓ Đã thêm video: Talking Learning Science with best-selling author Scott H. Young
# ✓ Đã thêm video: The 10-minute memory method
# ✓ Đã thêm video: What I Learned After Coaching 3000 Top Students
# ✓ Đã thêm video: How to Never Lose Focus Again
# ✓ Đã thêm video: You're not Lazy: How to End Procrastination For Life
# ✓ Đã thêm video: What I Learned after 5000 Hours of Studying
# ✓ Đã thêm video: How I changed my life in 334 days with Reverse Goal Setting
# ✓ Đã thêm video: Learning Expert plays Overrated Underrated with Study Techniques
# ✓ Đã thêm video: How I Ranked 1st at Monash University: 4-step Framework
# ✓ Đã thêm video: Study music is Overrated: Learning Expert Explains WHY
# ✓ Đã thêm video: 4 Reasons Hard Work DOES NOT Beat Talent
# ✓ Đã thêm video: Learning Expert Reacts to Top Medical Student Advice
# ✓ Đã thêm video: How CEOs Need to Learn
# ✓ Đã thêm video: Learning Coach Rates Productivity Apps
# ✓ Đã thêm video: Learning Coach Reacts to TikTok Studying Advice | Part 1
# ✓ Đã thêm video: I tried Nootropics for 30 days...
# ✓ Đã thêm video: Effective Journaling, Second Brain, Dopamine Detox, and more! | Two Minute Tuesday
# ✓ Đã thêm video: 4-Step Guide to break away from the herd!
# ✓ Đã thêm video: Overrated or Underrated: Active Recall, Mindmapping, Tutoring, Study Abroad, Scheduling & More!
# ✓ Đã thêm video: What are the BEST apps for Learning? - Q/A (Youtube comments edition)
# ✓ Đã thêm video: Week in the Life of an Edupreneur
# ✓ Đã thêm video: I got called out by a Stanford learning scientist
# ✓ Đã thêm video: The ultimate guide for studying with ChatGPT
# ✓ Đã thêm video: Why your IQ doesn't really matter?
# ✓ Đã thêm video: Better than Time Blocking AND Pomodoro?!
# ✓ Đã thêm video: How Avoiding Stress Can LEAD to Burnout
# ✓ Đã thêm video: How to Unlock Your Memory Potential
# ✓ Đã thêm video: Are you secretly a Bad Learner?
# ✓ Đã thêm video: Using "Interleaving" for Language Learning | TEDx Interview
# ✓ Đã thêm video: How to "Snowball" Your Learning | TEDx Interview
# ✓ Đã thêm video: Why Stress is Actually a Good Thing
# ✓ Đã thêm video: How to Turn PASSIVE Learning Into ACTIVE Learning (and Reduce Drowsiness)
# ✓ Đã thêm video: My Ultimate Rules for Staying Productive (And How YOU Can Follow Them Too)
# ✓ Đã thêm video: How to Cram the Right Way for Exams
# ✓ Đã thêm video: Revision Tips: How to Make Your Revision More TARGETED
# ✓ Đã thêm video: I lived like Elon for 1 year...
# ✓ Đã thêm video: Rating studying and productivity techniques | Underrated Overrated
# ✓ Đã thêm video: Your teacher can't help you... @KoiAcademy
# ✓ Đã thêm video: Upgrade Your Note-Taking the Easy Way
# ✓ Đã thêm video: Can AI Help Me Learn Faster? (DALL E 2)
# ✓ Đã thêm video: How #1 Nation-Ranked Students Evolve Their Learning
# ✓ Đã thêm video: Are Mind Maps a WASTE OF TIME?
# ✓ Đã thêm video: How to NEVER Burn Out again: 3-Step framework
# ✓ Đã thêm video: What Everyone Gets WRONG About Spaced Repetition
# ✓ Đã thêm video: The Trick to Permanent Motivation (Productivity Coach)
# ✓ Đã thêm video: My Most POWERFUL Study Trick (Any Subject)
# ✓ Đã thêm video: The 2 MUST-HAVE Ingredients to Study Efficiently
# ✓ Đã thêm video: 5 Ways to Train Yourself to Be a Genius (3 Short-term, 2 Long-term)
# ✓ Đã thêm video: How I Find The Perfect Book For Any Problem (Blinkist vs Shortform)
# ✓ Đã thêm video: 4 Tips to Read Without Losing Focus
# ✓ Đã thêm video: The Right Way to take notes in Chemistry
# ✓ Đã thêm video: Spend 1 Hour Studying to Save 20 Hrs Later
# ✓ Đã thêm video: Studying My Masters in 1/6th of the Time
# ✓ Đã thêm video: Study More Efficiently With These 2 Basic Steps
# ✓ Đã thêm video: 4 Steps to Read Difficult Texts Faster (Academic Speed Reading Comprehension)
# ✓ Đã thêm video: "Commit or Quit" is Toxic | E6 Bigger Plate
# ✓ Đã thêm video: Turning your brain off with Focus training | E5 Bigger Plate
# ✓ Đã thêm video: Aiming for Long term Goals can Increase Failure | E4 Bigger Plate
# ✓ Đã thêm video: Learn faster and retain more than your friends | E3 Bigger Plate
# ✓ Đã thêm video: Don't Memorise - The Real Consequences of Over-Memorisation
# ✓ Đã thêm video: E2: A Smarter Way to Work (BETTER than Pomodoro)
# ✓ Đã thêm video: Why Pomodoro Doesn't Work (Better Alternative by an Efficiency Coach)
# ✓ Đã thêm video: E1: Do More Without Working Harder (Eisenhower Matrix + 3 Common Issues)
# ✓ Đã thêm video: Why the Pomodoro Technique REALLY Works
# ✓ Đã thêm video: Myths About Efficiency (Why Busy People Have More Free Time)
# ✓ Đã thêm video: 5 Techniques of Every Successful Student
# ✓ Đã thêm video: What is Priming? Increase Learning by 40% | Study Clinic
# ✓ Đã thêm video: How "Proactive" Students Still Fall Behind
# ✓ Đã thêm video: Every Student Should... MEDITATE? | Study Clinic
# ✓ Đã thêm video: Why 90% of Students Never IMPROVE | Study Clinic
# ✓ Đã thêm video: Is Tutoring Worth it? (By a 10+ Years Tutor)
# ✓ Đã thêm video: Why NOTES kill good studying | Study Clinic
# ✓ Đã thêm video: Highschool standards don't matter | Study Clinic
# ✓ Đã thêm video: Doctors vs Social Enterprise (And How the Public Harms Them BOTH)
# ✓ Đã thêm video: Write 10x LESS NOTES and 2x Better Grades | STUDY CLINIC
# ✓ Đã thêm video: Let Me Change The Way You Write Notes Forever | Correct Mindmapping Technique
# ✓ Đã thêm video: Revision Mistake Even High Achievers Make | STUDY CLINIC
# ✓ Đã thêm video: Study 5 Lectures Simultaneously | STUDY CLINIC
# ✓ Đã thêm video: How to Revise EFFICIENTLY | STUDY CLINIC
# ✓ Đã thêm video: How Efficient Learners Think Differently | STUDY CLINIC
# ✓ Đã thêm video: The Truth About Open Book Exams | STUDY CLINIC
# ✓ Đã thêm video: Why Time Management Isn't the Problem (Attention and Focus Management)
# ✓ Đã thêm video: How To DO MORE After Work/School
# ✓ Đã thêm video: Productivity is BOTH Pointless AND Purposeful... ?!!
# ✓ Đã thêm video: One of my top 3 productivity hacks - Minimum Viable Goals (MVG)
# ✓ Đã thêm video: Vlog 1: The most perfectly AVERAGE day
# ✓ Đã thêm video: Doctor Reveals His 4-Step Sleep Routine | STRAY THOUGHT KILLER
# ✓ Đã thêm video: Patient Consent is a Lie (By an Ex-Doctor)
# ✓ Đã thêm video: Starting a company during medical school
# ✓ Đã thêm video: Doctor Tries to Become a Doctor in Nigeria (RealLives)
# ✓ Đã thêm video: Video Games Made Me LESS Lazy (As an Ex-Doctor)
